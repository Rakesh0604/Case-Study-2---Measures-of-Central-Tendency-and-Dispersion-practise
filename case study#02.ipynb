# %% [markdown]
# # Case Study on Measures of Central Tendency and Dispersion

# %% [markdown]
# # An Institution wishes to find out their student’s ability in maths, reading and writing skills. The Institution wants to do an exploratory study to check the following information.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

data = pd.read_csv('StudentsPerformance.CSV')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # 1. Find out how many males and females participated in the test.

# %%
male_data = data[data['gender']=='male']
female_data = data[data['gender']=='female']
print('Total number of males participated in the test=',male_data['gender'].count())
print('\nTotal number of femmales participated in the test=',female_data['gender'].count())
# Out:
# Total number of males participated in the test= 482
#
# Total number of femmales participated in the test= 518

# %% [markdown]
# # 2. What do you think about the students' parental level of education?

# %%
plt.figure(figsize=(15,10))
sns.countplot(data['parental level of education'], palette = 'Blues')
plt.title('Comparison of Parental Education',fontsize = 20)
plt.xlabel('Degree')
plt.ylabel('count')
plt.show()

# %% [markdown]
# # 3. Who scores the most on average for math, reading and writing based on

# %% [markdown]
# # ● Gender

# %%
data[['test preparation course',
      'gender',
      'math score',
      'writing score',
      'reading score']].groupby(['gender']).agg('mean')
# Out:
#         math score  writing score  reading score
# gender
# female   63.376448      72.467181      72.590734
# male     68.821577      63.446058      65.545643

# %% [markdown]
# # ● Test preparation course

# %%
data[['test preparation course',
      'gender',
      'math score',
      'writing score',
      'reading score']].groupby(['test preparation course','gender']).agg('mean')
# Out:
#                                 math score  writing score  reading score
# test preparation course gender
# completed               female   67.108696      78.793478      77.375000
#                         male     72.988506      70.339080      70.793103
# none                    female   61.320359      68.982036      69.955090
#                         male     66.467532      59.551948      62.581169

# %% [markdown]
# # 4. What do you think about the scoring variation for math, reading and writing based on

# %% [markdown]
# # ● Gender

# %%
i=1
plt.figure(figsize=(20,7),facecolor='w')
for item in data.columns[-2:]:
    plt.subplot(1,2,i)
    sns.boxplot(x=data['gender'], y=data[item])
    plt.title(item+" vs Gender",size=14)
    i+=1
plt.show()

# %% [markdown]
# # ● Test preparation course

# %%
i=1
plt.figure(figsize=(20,7),facecolor='w')
for item in data.columns[-3:]:
    plt.subplot(1,3,i)
    sns.boxplot(x=data['test preparation course'], y=data[item])
    plt.title(item+" vs pre test",size=14)
    i+=1
plt.show()

# %% [markdown]
# # 5. The management needs your help to give bonus points to the top 25% of students based on their maths score, so how will you help the management to achieve this.

# %%
data_bonus = data.nlargest(250, ['math score'])                   
print('List of students eligible for bonus/n',data_bonus)
# Out:
# List of students eligible for bonus/n      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 428  female        group D                some college  free/reduced
# 429  female        group E            some high school      standard
# 849    male        group A           bachelor's degree      standard
# 850    male        group C          associate's degree  free/reduced
# 851    male        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...
